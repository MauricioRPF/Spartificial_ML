# %% [markdown]
# # <center> W2S3 - Pandas and Scikit Image
#
# ---

# %% [markdown]
# **So far in this week:-**
# * Control Flow and Functions
# * NumPy
# * Matplotlib
#
# **In this notebook we will cover:-**
# * Pandas
# * Sci-kit Image

# %% [markdown]
# ### **Pandas**
#
# * How to read csv files?
# * Explore a csv file using pandas data frame
# * Data Exploration using Pandas

# %% [markdown]
# ## Step 1:- Adding the Dataset to your Google Colab Notebook
# * Download the dataset from [this link](https://drive.google.com/uc?id=1dVK2MgtXvrSOVBVodKhlAf0XMIa-2jGF).

# %% [markdown]
# ## Step 2:- Read the CSV Data
# * Upload the csv file to the session storage of the colab
# * You can find the complete details about this data [over here](https://www.kaggle.com/datasets/lucidlenn/sloan-digital-sky-survey/data).
# * [Understanding SDSS Imagining](https://www.sdss3.org/dr10/imaging/imaging_basics.php)
# * [Terminologies Explained](https://www.sdss3.org/dr10/help/glossary.php)

# %%
# Use Pandas to read the csv dataaaaaaaaaaaa
import pandas as pd

# %%
# Storing the CSV data in pandas DataFrame
path_to_csv = 'https://raw.githubusercontent.com/MauricioRPF/Spartificial_ML/main/W2S3_Content_SDSS%20Tabular%20Data.csv' # I had stored my csv data within MyDrive > Program Datasets > SDSS Tabular Data.csv
df = pd.read_csv(path_to_csv)
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598370   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# ...

# %%
# @title class vs g

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['class'].unique()))
plt.figure(figsize=figsize)
classVSg = sns.violinplot(df, x='g', y='class', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-21-9efccdcc5120>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   classVSg = sns.violinplot(df, x='g', y='class', inner='box', palette='Dark2')

# %%
# @title objid vs dec

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['objid']
  ys = series['dec']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('objid', ascending=True)
for i, (series_name, series) in enumerate(df_sorted.groupby('class')):
  _plot_series(series, series_name, i)
  fig.legend(title='class', bbox_to_anchor=(1, 1), loc='upper left')
sns.despine(fig=fig, ax=ax)
plt.xlabel('objid')
_ = plt.ylabel('dec')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Display first 5 rows of data from the df
df.head(5) # try tail, sample instead of head if you like (check recording for more details)
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598370  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %%
# Shape of df
df.shape
# Out:
# (10000, 18)

# %%
# Check the basic info about this dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# ...

# %% [markdown]
# ## Step 3:- Create Visualizations

# %%
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
# Check the count of galaxy, star and qasar in our data

# Adjusting the Figure Size
plt.figure(figsize = (10, 10))

''' We can plot directly using pandas '''
# value_counts() gives counts of unique values in the column it is used on
colors = ['blue', 'pink', 'purple']
ax = df['class'].value_counts().plot(kind = 'bar', color = colors) # kind can be (line, hist, bar, box, pie, etc...)

# Using ax (axis) to display the bar_label using containers[0] as thats where the location is of the counts
ax.bar_label(ax.containers[0], color='black', weight='bold')

# Customizing the Plot a bit more
plt.xticks(weight='bold', rotation=0)
plt.title('Visualizing the distribution of Classes in the Data', color='r', weight='bold', fontsize=12)

# Save the Figure and Display the output
plt.savefig('ClassDistribution.png') # You can download the visualization from files section (left panel)
plt.show()

# %%
# We can also create a data frame from numpy arrays!
import numpy as np

# Define Arrays
array_1 = np.array([1, 2, 3, 4, 5])
array_2 = np.array(['A', 'B', 'C', 'D', 'E'])

# Create DataFrame
df_from_array = pd.DataFrame(zip(array_2, array_1), columns = ['Col 1', 'Col 2'], index = [f'Row {i}' for i in range(1, 6)])

# Display it
df_from_array
# Out:
#       Col 1  Col 2
# Row 1     A      1
# Row 2     B      2
# Row 3     C      3
# Row 4     D      4
# Row 5     E      5

# %%
# Save your data frame using to_csv method of Pandas
df_from_array.to_csv('SampleDataFrame.csv')

# %% [markdown]
# ### **Scikit-Image**
#
# * Add any image to Google Colab (I will use the one I have for this session)
# * How to read the image using skimage
# * How to visualize the image array
# * How to use slicing to crop the image

# %%
import requests

# URL of the image from GitHub
url = 'https://github.com/MauricioRPF/Spartificial_ML/blob/main/W2S3_Content_Moon-Pleiades-AirplaneLR.jpg?raw=true'

# Download the image
response = requests.get(url)

# Save the image to a file
with open('image.jpg', 'wb') as file:
    file.write(response.content)

# Display the image
from IPython.display import Image
Image('image.jpg')

# %%
# Get the imread from skimage's io
from skimage.io import imread

# %%
# Read the image path and convert it to array of pixels
img_array = imread('image.jpg')

# %%
# What is the shape of this image?
print(img_array.shape)
# Out:
# (480, 320, 3)

# %% [markdown]
# **Understand the shape of this image_array**:-
#
# * Axis 0:- Rows
# * Axis 1:- Cols
# * Axis 3:- Channels
#
# * If channels = 3, then it represents RGB (Red, Green, and Blue Channels)
#
# * If channel = 1 (or only 2D array) then it represents a gray scale output.

# %%
# Check the image array
print(img_array)
# Out:
# [[[12 12 12]
#   [12 12 12]
#   [11 11 11]
#   ...
#   [13 11 12]
#   [12 10 11]
#   [11  9 10]]
#
#  [[12 12 12]
#   [12 12 12]
#   [11 11 11]
#   ...
#   [13 11 12]
#   [13 11 12]
#   [13 11 12]]
#
#  [[12 12 12]
#   [12 12 12]
#   [11 11 11]
#   ...
#   [13 11 12]
#   [13 11 12]
#   [13 11 12]]
#
#  ...
#
#  [[11 11 11]
#   [10 10 10]
#   [10 10 10]
#   ...
#   [10  8  9]
#   [10  8  9]
#   [ 9  7  8]]
#
#  [[11 11 11]
#   [11 11 11]
#   [11 11 11]
#   ...
#   [10  8  9]
#   [11  9 10]
#   [10  8  9]]
#
#  [[10 10 10]
#   [10 10 10]
#   [10 10 10]
#   ...
#   [11  9 10]
#   [12 10 11]
#   [10  8  9]]]

# %%
# What are minimum and maximum values in this array?
print(f'Min:- {img_array.min()}\nMax:- {img_array.max()}')
# Out:
# Min:- 0
# Max:- 255

# %%
# This is uint-8 datatype - crosscheck it
img_array.dtype
# Out:
# dtype('uint8')

# %%
# Visualize the image
plt.imshow(img_array[:, :, 0], cmap = 'gray')
plt.show()

# %%
plt.imshow(img_array[:, :, 0], cmap = 'viridis')
plt.show()

# %%
# Grayscale output
plt.imshow(img_array[:, :, 2], cmap='gray') # 0 - red, 1 - green, 2 - blue
plt.show()

# %%
# Slice the moon and the pleiades constellation
constellation = img_array[60:120, 50:140, :]
moon = img_array[185:233, 214:264, :]

# Tuple to store the data for plotting
plot_data = (
    (constellation, moon),
    ('Pleiades', 'Moon'),
    ('blue', 'gray')
)


# Using for loop to loop through the tuple to create subplot
for index, (data, title, color) in enumerate(zip(*(plot_data))):
  plt.subplot(1, 2, index + 1)
  plt.imshow(data)
  plt.title(title, color = color)
  plt.axis('off')


# Adjust the layout and display the output
plt.tight_layout()
plt.show()
